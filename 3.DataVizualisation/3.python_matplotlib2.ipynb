# %% [markdown]
# # Matplotlib

# %% [markdown]
# Pour tracer des figures, afin de visualiser nos  données, on utilise le package $\textbf{pyplot}$ qui se trouve dans $\textbf{matplotlib}$
# On commence par l'importer come suit:

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Il existe deux methodes pour la représentation des donnees:
# - la méthode : $\textbf{plt.plot()}$
# - et la méthode de la promgrammation orientée objet (POO)  $\textbf{fig, ax = plt.subplots()}$

# %% [markdown]
# ## 1- Methode plt.plot()

# %% [markdown]
# Notre première figure.
# Remarque :
# - pour afficher les images dans la console, on ecrit dans une des cellules au moins une fois la ligne $\textbf{%matplotlib inline}$
#
# - Pour sortir la figure, on ecrit plutôt $\textbf{%matplotlib qt5}$

# %%
# !pip install matplotlib

# %%
# %matplotlib inline
plt.plot([1,2,3,4])
plt.ylabel("des nombres $x^2$")
plt.show()

# %% [markdown]
# Remarque : Si la fonction plot reçoit un tableau de données, elle l'utilisera comme
# coordonnées sur l'axe vertical, et elle utilisera simplement l'index de
#  chaque point de données dans le tableau comme coordonnée horizontale.

# %% [markdown]
# Vous pouvez également fournir deux tableaux : un pour l'axe horizontal x,
# et le second pour l'axe vertical y :

# %%
plt.plot([-3,-2,5,0],[1,6,4,3])
plt.show()

# %% [markdown]
# Les axes correspondent automatiquement à l'étendue des données.
# Nous aimerions donner un peu plus d'espace au graphique,
# alors appelons la fonction $\textbf{axis}$ pour modifier l'étendue
# de chaque axe $\textbf{[xmin, xmax, ymin, ymax]}$.

# %%
plt.plot([-3,-2,5,0],[1,6,4,3])
plt.axis([ -4 ,6, 0, 7])
plt.show()

# %% [markdown]
# On peut tracer plusieurs fonctions sur la meme figure. Il est recommender
# d'utiliser $\textbf{plt.figure}$ pour pouvoir definir la taille de sa figure.
#
# On peut
# - rajouter des étiquettes aux differentes courbes : mot clé $\textbf{label}$
# - modifier l'épaisseur des lignes: mot clé $\textbf{linewidth}$ ou  $\textbf{lw}$
# - modifier le type de trait on utilise le mot clé : $\textbf{c}$

# %%
import numpy as np

t = np.arange(0., 5., 0.2)
t

plt.plot(t,t,'r--', label='lineaire',lw = 7)
plt.plot(t,t**2,'bs', label= 'carree')
plt.plot(t,t**3,'g^', label='cube')
plt.grid()
plt.legend()
plt.show()

plt.savefig('ma_figure.svg')

# %% [markdown]
# Un autre exemple ave la fonction carrée en utilisant LaTex dans les labels

# %%
x = np.linspace(-1.4,1.4,500) # je genere 500 valeurs entre -1.4 et 1.4
y =x**2
plt.plot(x,y)
plt.title(" fonction carree")
plt.xlabel("x")
plt.ylabel("$y = x^2$")
plt.grid()
plt.show()

# %% [markdown]
# Par défaut, matplotlib dessine une ligne entre des points consécutifs. On peut par exemple avoir ce type de dessin

# %%
#on s'amuse à dessiner une enveloppe

plt.plot([0,100,100,0,0,100,50,0,100],[0,0,100, 100,0,100,130,100,0])
plt.axis([-10,110, -10,140])

plt.show()

# %% [markdown]
# Un autre exemple avec un type de trait  et de couleur différent

# %%
plt.plot([0, 100, 100, 0, 0, 100, 50, 0, 100], \
         [0, 0, 100, 100, 0, 100, 130, 100, 0], "g--")
plt.axis([-10, 110, -10, 140])
plt.show()

# %% [markdown]
# On peut avoir les deux types de traits

# %%
plt.figure()
plt.plot([0, 100, 100, 0, 0], [0, 0, 100, 100, 0], "r-")
plt.plot([0, 100, 50, 0, 100], [0, 100, 130, 100, 0], "g--")
plt.axis([-10, 110, -10, 140])
plt.show()

# %% [markdown]
# ### Subplot

# %% [markdown]
# Une figure matplotlib peut contenir plusieurs sous-plans.
# Ces sous-plots sont organisés dans une grille. Pour créer un sous-plot,
# il suffit d'appeler la fonction subplot, et de spécifier le nombre de lignes
# et de colonnes de la figure, ainsi que l'indice du sous-plot sur lequel vous
# souhaitez dessiner (en commençant par 1, puis de gauche à droite, et de haut en bas)

# %%
x = np.linspace(-1.4,1.4,30)

plt.subplot(2,2,1)
plt.plot(x,x)
plt.title('lineaire')

plt.subplot(2,2,2)
plt.plot(x,x**2)
plt.title('carree')

plt.subplot(223)
plt.plot(x,x**3)
plt.title('cube')

plt.subplot(2,2,4)
plt.plot(x,x**4)
plt.title('puissance 4')

plt.show()

# %% [markdown]
# Notez que $\textbf{subplot(223)}$ est un raccourci pour $\textbf{subplot(2, 2, 3)}$.

# %% [markdown]
# On peut aussi créer des sous-plots qui s'étendent sur plusieurs cellules de la grille, comme suit :

# %%
plt.subplot(2,2,1)
plt.plot(x,x)
plt.title('lineaire')

plt.subplot(2,2,2)
plt.plot(x,x**2)
plt.title('carree')

plt.subplot(2,1,2)
plt.plot(x,x**3)
plt.title('cube')
plt.show()

# %% [markdown]
# # 2 - Methode  orientée Objet POO

# %%
fig, ax = plt.subplots(2,1)
print(type(ax),ax.shape)
y = x**2
ax[0].plot(x,y)
ax[1].plot(x,y)

plt.show()
# Out:
# <class 'numpy.ndarray'> (2,)

# %%
# ici ax est un tableau numpy. On pet le voir en verifiant quelques propriets
type(ax)
ax.shape
# Out:
# (2,)

# %%
# Reprise de l'exemple du poly

def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)

t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)

fig, (ax1, ax2) = plt.subplots(2, 1)
ax1.plot(t1, f(t1), 'bo', t2, f(t2),'k')
ax2.plot(t2, np.cos(2*np.pi*t2), 'r--', linewidth=2.0)

# %%
# un autre exemple

x = np.linspace(-1.4, 1.4, 30)
line1, line2, line3 = plt.plot(x, x, 'g--', x, x**2, 'r:', x, x**3, 'b^')

line1.set_linewidth(3.0)
line2.set_linewidth(3.0)
line1.set_dash_capstyle("round")
line3.set_alpha(0.2)
plt.grid()
plt.show()

# %% [markdown]
# ### Echelles non-linéaires

# %% [markdown]
# Matplotlib supporte les échelles non linéaires, comme les échelles logarithmiques ou logit.

# %%
x = np.linspace(0.1, 15,500)
y = x**3/np.exp(2*x)

plt.figure(1)
plt.plot(x,y)
plt.yscale('linear')
plt.title('lineaire')
plt.grid()
plt.show()



plt.figure(1)
plt.plot(x,y)
plt.yscale('log')
plt.title('log')
plt.grid()
plt.show()

# %% [markdown]
# $\textbf{exercice}$  : representer sur un même graphique plusieurs fonctions qui sont le resultat de
#  plusieurs experiences

# %%
# on commence par créé des données 

nbre_total_exp = 6
dataset = {f"experience{i}":np.random.randn(100,3) for i in range(nbre_total_exp)}
dataset
# Out:
# {'experience0': array([[-0.13212965, -0.25032347,  0.09776065],
#         [ 1.19964806,  0.60490658,  1.11452766],
#         [ 0.04634938, -0.17510465,  0.06041587],
#         [-0.52297034, -1.77267008, -0.00584042],
#         [ 1.05893308, -0.62030283,  0.28259984],
#         [-2.43588467, -0.38470688, -1.60544645],
#         [-1.68664168, -1.11457505,  0.13061338],
#         [-1.14437979,  1.70100583,  0.87241877],
#         [-0.15599205, -1.48606809, -0.06244148],
#         [ 0.50987671, -1.42386861, -0.4228404 ],
#         [-0.6996466 , -0.39701357, -0.60724985],
#         [-0.11885377, -0.43132684, -0.58087635],
#         [-0.1881222 ,  1.53894797, -0.93000537],
#         [-0.45281583,  1.27476379, -1.53568091],
#         [-1.33171026,  1.75509984,  0.66570998],
#         [ 0.43003785,  1.31114506, -1.33647367],
#         [ 0.20745754,  0.08123096, -0.25603736],
#         [-0.26417709, -0.17358893, -1.04676775],
#         [-1.14126997,  1.02750965, -1.02217969],
# ...

# %% [markdown]
# On fait ensuite une petite fonction qui nous permettra de les afficher. Cette fonction peut etre tres utile pour le reste

# %%
def graphique(data):
    n = len(data)
    plt.figure(figsize=(12,8))
    for k , i in zip(data.keys(), range(1,n+1)):
        plt.subplot(n,1,i)
        plt.plot(data[k])
        plt.title(k)
    plt.show()

# %%
graphique(dataset)

# %% [markdown]
# #on affiche nos données
#
# graphique(dataset)
#
# # on peut modifier le nombre total d'experience dans nbre_total_exp et le code qui
# # affiche continuera de fonctionner

# %% [markdown]
# ## Dessin de texte
#
# Vous pouvez ajouter du texte à n'importe quel endroit du graphique. Il suffit de spécifier les coordonnées horizontales et verticales et le texte, et éventuellement quelques attributs supplémentaires. Tout texte dans matplotlib peut contenir des expressions d'équation TeX, (voir la documentation pour plus de détails).

# %%
# un exemple

x = np.linspace(-1.5, 1.5, 30)
px = 0.8
py = px**2

plt.plot(x, x**2, "b-", px, py, "ro")

plt.text(0, 1.5, "function carree\n$y = x^2$", fontsize=20, color='blue', horizontalalignment="center")
plt.text(px - 0.08, py, " un point", ha="right", weight="heavy")
plt.text(px, py, "x = %0.2f\ny = %0.2f"%(px, py), rotation=50, color='gray')

plt.grid()
plt.show()

# %% [markdown]
# - Remarque : ha est un alias de horizontalalignment.
#
# Pour d'autres propriétés de texte, consultez la documentation.
#
# Il est assez fréquent d'annoter des éléments d'un graphique, comme le beau point ci-dessus.
# La fonction d'annotation facilite cette tâche :
# il suffit d'indiquer l'emplacement du point d'intérêt et la position du texte,
# plus éventuellement quelques attributs supplémentaires pour le texte et la flèche.

# %%
plt.plot(x, x**2, px, py, "ro")
plt.annotate("un point", xy=(px, py), xytext=(px-1.3,py+0.5),
                           color="green", weight="heavy", fontsize=14,
                           arrowprops={"facecolor": "lightgreen"})

plt.grid()
plt.show()

# %% [markdown]
# Vous pouvez également ajouter une boîte de délimitation autour de votre texte en utilisant l'attribut bbox :

# %%
plt.plot(x, x**2, px, py, "ro")

bbox_props = dict(boxstyle="rarrow,pad=0.3", ec="b", lw=2, fc="lightblue")
plt.text(px-0.2, py, "Un point", bbox=bbox_props, ha="right")

bbox_props = dict(boxstyle="round4,pad=1,rounding_size=0.2", ec="black", fc="#EEEEFF", lw=5)
plt.text(0, 1.5, "fonction carree\n$y = x^2$", fontsize=20, color='black', ha="center", bbox=bbox_props)

plt.grid()

plt.show()

# %% [markdown]
# # 3- Types de figures

# %% [markdown]
# ## Le nuage de points: scatter

# %% [markdown]
# Pour dessiner un nuage de points, il suffit de fournir les coordonnées x et y des points.

# %%
x,y = np.random.rand(2,100)
plt.scatter(x,y)

plt.show()

# %% [markdown]
# Vous pouvez également indiquer l'échelle de chaque point.

# %%
x,y,scale = np.random.rand(3,100)
scale = 500*scale**5
plt.scatter(x,y,s=scale)
plt.show()

# %% [markdown]
# Et comme d'habitude, vous pouvez définir un certain nombre d'autres attributs, tels que les couleurs de remplissage et de bordure et le niveau alpha.

# %%
for color in ['red','green','blue']:
    n = 100
    x,y = np.random.rand(2,n)
    scale=500*np.random.rand(n)**5
    plt.scatter(x,y,s =scale,c=color, alpha=0.3)
    
plt.grid()
plt.show()

# %% [markdown]
# Un dernier exemple avec la fleur d'iris

# %%
from sklearn.datasets import load_iris


iris = load_iris()
X = iris.data
y = iris.target

## on affiche les informations de ces variables


names = list(iris.target_names)
print(f"X contient {X.shape[0]} exemples et {X.shape[1]}  variables")
print(f"Il ya {np.unique(y).size} classes")


plt.scatter(X[:,0],X[:,1], c=y, alpha=0.4, s=X[:,2]*100)

plt.xlabel("longueur sepal")
plt.ylabel("largeur sepal")

plt.grid()
plt.show()
# Out:
# X contient 150 exemples et 4  variables
# Il ya 3 classes

# %% [markdown]
# ## Histogramme

# %% [markdown]
# Ils sont tres importants lorsqu'on manipule les données. Ils nous permmetent
# de voir la distribution de nos donnees . Si la distribution est normale ou non, symétrique ou asymétrique ou bien encore de visualiser la moyennne. On peut voir comment les fleurs sont distribuées

# %%
# un exemple avec la fleur d'iris avec modification du nombre de bins

plt.hist(X[:,0], bins=30)
plt.hist(X[:,1], bins=30)
plt.grid()
plt.show()

# %%
#un autre exemple
data = [1, 1.1, 1.8,2,2.1,3.2,3,3,3,3,3]

plt.subplot(211)
plt.hist(data, bins = 10)

plt.subplot(212)
plt.hist(data, bins = [1, 1.5,2, 2.5,3])

plt.show()

# %% [markdown]
# On peut dessiner des histogrammes sur le même graphique (reprise fleur d'iris avec les deux premières données)

# %%
data1 = np.random.randn(400)
data2 = np.random.randn(500) + 3
data3 = np.random.randn(450) + 6
data4 = np.random.randn(200) + 9
data5 = np.random.randn(100) + 10


plt.hist(data1, bins=5, color='g', alpha=0.75, label='bar hist') # par defaut
plt.hist(data2, color='b', alpha=0.5, histtype= 'stepfilled',label='stepfilled hist')
plt.hist(data3, color='r', alpha=0.65, histtype= 'step',label='step hist')
plt.hist((data4, data5), color=('r','m'), alpha=0.55, histtype= 'barstacked',
         label=('barstacked 1', 'barstacked 2'))



plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 11
#       9 plt.hist(data2, color='b', alpha=0.5, histtype= 'stepfilled',label='stepfilled hist')
#      10 plt.hist(data3, color='r', alpha=0.65, histtype= 'step',label='step hist')
# ---> 11 plt.hist((data4, data5), color=('r','m'), alpha=0.55, histtype= 'barstacked',
#      12          label=('barstacked 1', 'barstacked 2'))
#      16 plt.legend()
#      17 plt.show()
#
# File ~\.conda\envs\Jupyter4researchers\lib\site-packages\matplotlib\pyplot.py:3224, in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    3199 @_copy_docstring_and_deprecators(Axes.hist)
#    3200 def hist(
#    3201     x: ArrayLike | Sequence[ArrayLike],
#    (...)
#    3222     BarContainer | Polygon | list[BarContainer | Polygon],
#    3223 ]:
# ...

# %% [markdown]
# Il y a aussi différents types d'histogrammmes et un certains nombres de paramètres qu'on peut modifier

# %%
plt.hist2d(X[:,0],X[:,2], cmap= 'Blues')
plt.colorbar()
plt.show()

# %% [markdown]
# On peut faire des histogramme en 2D

# %%
from scipy import misc

face = misc.face(gray=True)
plt.imshow(face, cmap= 'gray')
plt.show()

# %% [markdown]
# On utilise les histogramme pour faire de l'analyse d'images :

# %%
plt.hist(face.ravel(), bins=255)
plt.grid()
plt.show()

# %% [markdown]
# # Images
#
# Lire, générer et tracer des images dans matplotlib est assez simple.
#
# Pour lire une image, il suffit d'importer le $\textbf{module matplotlib.image}$, et d'appeler sa fonction $\textbf{imread}$, en lui passant le nom du fichier (ou l'objet fichier). Cela renvoie les données de l'image, sous la forme d'un tableau NumPy.
#                                                                                             Essayons ceci avec l'image $\textbf{ma_figure.png}$ que nous avons sauvegardée plus tôt.

# %%
import matplotlib.image as mpimg
img = mpimg.imread('ma_figure.png')

print(img.shape)
print(img.dtype)



plt.imshow(img)
# plt.imshow('off')
plt.show()
# Out:
# (480, 640, 4)
# float32

# %% [markdown]
# # la fonction imshow() permet d'afficher une matrice de correlation

# %%
plt.imshow(np.corrcoef(X.T), cmap="Blues")
plt.show()

# %%
from sklearn.datasets import load_breast_cancer
cancer = load_breast_cancer()

X = cancer.data

plt.imshow(np.corrcoef(X.T), cmap="Blues")
plt.colorbar()
plt.show()

# %% [markdown]
# On peut créer notre propre image

# %%
img = np.arange(100*100).reshape(100,100)
print(img)
plt.imshow(img)
plt.show()
# Out:
# [[   0    1    2 ...   97   98   99]
#  [ 100  101  102 ...  197  198  199]
#  [ 200  201  202 ...  297  298  299]
#  ...
#  [9700 9701 9702 ... 9797 9798 9799]
#  [9800 9801 9802 ... 9897 9898 9899]
#  [9900 9901 9902 ... 9997 9998 9999]]

# %% [markdown]
# Comme nous n'avons pas fourni de niveaux RGB, la fonction imshow fait automatiquement correspondre les valeurs à un dégradé de couleurs. Par défaut, le gradient de couleur va du bleu (pour les valeurs faibles) au rouge (pour les valeurs élevées), mais vous pouvez sélectionner une autre carte de couleurs. Par exemple :

# %%
img = np.empty((20,30,3))
img[:,:10] = [0,0,0.6]
img[:,10:20] = [1,1,1]
img[:,20:] = [0.6,0,0]

plt.imshow(img)
plt.show()

# %% [markdown]
# Vous pouvez souhaiter masquer les axes lorsque vous affichez une image :

# %%
plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# On peut generer notre propre image

# %% [markdown]
# Puisque le tableau img est tout simplement assez petit (20x30), lorsque la fonction imshow l'affiche, elle agrandit l'image à la taille de la figure. Par défaut, elle utilise l'interpolation bilinéaire pour remplir les pixels ajoutés. C'est pourquoi les bords semblent flous. Vous pouvez sélectionner un autre algorithme d'interpolation, par exemple en copiant la couleur du pixel le plus proche :

# %%
img = np.empty((20,30,3))
img[:,:10] = [0,0,0.6]
img[:,10:20] = [1,1,1]
img[:,20:] = [0.6,0,0]

plt.imshow(img, interpolation="nearest")
plt.axis('off')
plt.show()

# %% [markdown]
# ## Figure en 3D

# %% [markdown]
# Pour tracer des graphiques en 3D vous devez importer Axes3D, qui enregistre la projection "3d". Ensuite, créez un sous-plot en fixant la projection à "3d". Cela renvoie un objet Axes3DSubplot, que vous pouvez utiliser pour appeler plot_surface, en donnant des coordonnées x, y et z, ainsi que des attributs optionnels.

# %%
# exemple avec la fleur d'iris

from mpl_toolkits.mplot3d import Axes3D
from sklearn.datasets import load_iris


iris = load_iris()
X = iris.data
y = iris.target


ax = plt.axes(projection = '3d')
ax.scatter(X[:,0],X[:,1],X[:,2])
plt.show()

# %%
# un autre exemple
x = np.linspace(-5,5,50)
y = np.linspace(-5,5,50)
X,Y= np.meshgrid(x,y)


R = np.sqrt(X**2 +Y**2)
Z = np.sin(R)


figure = plt.figure(1, figsize = (12,4))
subplot3d = plt.subplot(111, projection='3d')
surface = subplot3d.plot_surface(X,Y,Z, cmap= plt.cm.coolwarm)
plt.show()

# %% [markdown]
# Une autre façon d'afficher ces mêmes données est d'utiliser un tracé de contour.

# %%
# un autre exemple pour finir :  une surface
plt.contour(X,Y,Z)
plt.colorbar()
plt.show()

# %%
ax = plt.axes(projection = '3d')
ax.plot_surface(X,Y,Z, cmap="plasma")

# %% [markdown]
# Vue de dessus d'un 3D :  contour plot

# %%
f = lambda x, y : np.sin(x) + np.cos(x+y)*np.cos(x)


X = np.linspace(0,5,200)
Y = np.linspace(0,5,200)


XX,YY = np.meshgrid(X,Y)


Z = f(XX,YY)

# %%
plt.contour(XX,YY,Z,20,colors='black')

plt.show()


plt.contourf(XX,YY,Z,20,cmap='RdGy')
plt.colorbar()

plt.show()

# %% [markdown]
# Mais lorsque vous écrivez un programme, l'explicite est préférable à l'implicite. Le code explicite est généralement plus facile à déboguer et à maintenir, et si vous ne me croyez pas, lisez la deuxième règle du Zen of Python :

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %% [markdown]
# ## on peut aller plus loin en faisant des animations :  voir la doc de matplotlib
